# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')

# %%
df1 = pd.read_csv("C:/Users/diksh/OneDrive/Desktop/Highway_safety_dashboard/data/combined_accident_data.csv")

# %%
print("Shape:",df1.shape)
print("Rows",df1.shape[0])
print("Columns:",df1.shape[1])
# Out:
# Shape: (1000, 29)
# Rows 1000
# Columns: 29

# %%
df1.head()
# Out:
#    Num_Acc inverse_data week_day state  severity weather location  hrmn  \
# 0  AID0001   2022-11-20        T    WB     Minor   Storm    Loc91  1958
# 1  AID0002   2023-12-09        T    TR    Severe     Fog   Loc184  2245
# 2  AID0003   2022-11-12        W    HP  Moderate     Fog    Loc77   250
# 3  AID0004   2023-02-13        T    CG    Severe   Clear    Loc78   545
# 4  AID0005   2022-11-25        S    TR  Moderate   Storm    Loc57  2146
#
#         lum vehicle_type vehicle_model  engine_size driver_sex  driver_age  \
# 0  Daylight          Car       Model41         1089          M          48
# 1  Daylight          Car        Model1         2653          F          21
# 2  Twilight          Car       Model21         2997          M          62
# 3     Night   Motorcycle       Model30         2079          M          26
# 4  Twilight          Car       Model23         2279          M          20
#
#    car_age casualty_severity  casualty_age casualty_sex social_class  \
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Num_Acc                        1000 non-null   object
#  1   inverse_data                   1000 non-null   object
#  2   week_day                       1000 non-null   object
#  3   state                          1000 non-null   object
#  4   severity                       1000 non-null   object
#  5   weather                        1000 non-null   object
#  6   location                       1000 non-null   object
#  7   hrmn                           1000 non-null   int64
#  8   lum                            1000 non-null   object
#  9   vehicle_type                   1000 non-null   object
#  10  vehicle_model                  1000 non-null   object
#  11  engine_size                    1000 non-null   int64
# ...

# %%
df1.isnull().sum()
# Out:
# Num_Acc                          0
# inverse_data                     0
# week_day                         0
# state                            0
# severity                         0
# weather                          0
# location                         0
# hrmn                             0
# lum                              0
# vehicle_type                     0
# vehicle_model                    0
# engine_size                      0
# driver_sex                       0
# driver_age                       0
# car_age                          0
# casualty_severity                0
# casualty_age                     0
# casualty_sex                     0
# social_class                     0
# casualty_type                    0
# pedestrian_or_passenger          0
# severity_description             0
# weather_description              0
# location_description             0
# vehicle_type_description         0
# engine_size_description          0
# driver_sex_description           0
# ...

# %%
df1.describe()
# Out:
#               hrmn  engine_size   driver_age      car_age  casualty_age
# count  1000.000000  1000.000000  1000.000000  1000.000000    1000.00000
# mean   1174.884000  1894.821000    44.234000     9.992000      40.86700
# std     675.151316   628.284385    15.301221     6.020646      22.85405
# min       1.000000   800.000000    18.000000     0.000000       1.00000
# 25%     557.000000  1328.000000    31.000000     5.000000      21.00000
# 50%    1143.000000  1901.000000    44.000000    10.000000      41.00000
# 75%    1753.250000  2439.250000    58.000000    15.000000      60.00000
# max    2359.000000  2997.000000    70.000000    20.000000      80.00000

# %%
#Dropping the descriptive columns
desc_cols=['severity_description', 'weather_description', 'location_description',
             'vehicle_type_description', 'engine_size_description',
             'driver_sex_description', 'casualty_severity_description',
             'casualty_type_description']
df1.drop(columns = desc_cols,inplace = True)
print("New Shape",df1.shape)
# Out:
# New Shape (1000, 21)

# %%
df1.rename(columns={'Num_Acc':'accident_id',
                    'inverse_data':'date',
                    'hrmn':'time',
                    'lum':'light_condition'
                   },inplace = True )
print(df1.columns.tolist())
# Out:
# ['accident_id', 'date', 'week_day', 'state', 'severity', 'weather', 'location', 'time', 'light_condition', 'vehicle_type', 'vehicle_model', 'engine_size', 'driver_sex', 'driver_age', 'car_age', 'casualty_severity', 'casualty_age', 'casualty_sex', 'social_class', 'casualty_type', 'pedestrian_or_passenger']

# %%
df1['date'] = pd.to_datetime(df1['date'])
df1['year'] = df1['date'].dt.year
df1['month'] = df1['date'].dt.month
df1['month_name'] = df1['date'].dt.strftime('%B')
df1[['date','year','month','month_name']].head()
# Out:
#         date  year  month month_name
# 0 2022-11-20  2022     11   November
# 1 2023-12-09  2023     12   December
# 2 2022-11-12  2022     11   November
# 3 2023-02-13  2023      2   February
# 4 2022-11-25  2022     11   November

# %%
df1['hour'] =df1['time'].astype(str).str.zfill(4).str[:2].astype(int)
def time_of_day(h):
    if 6<=h<12:
        return'Morning'
    elif 12<=h<17:
       return 'Afternoon'
    elif 17<=h<21:
        return 'Evening'
    else:
       return 'Night'
df1['time_of_day'] = df1['hour'].apply(time_of_day)
df1[['time', 'hour', 'time_of_day']].head()
# Out:
#    time  hour time_of_day
# 0  1958    19     Evening
# 1  2245    22       Night
# 2   250     2       Night
# 3   545     5       Night
# 4  2146    21       Night

# %%
df1.to_csv('../data/cleaned_accident_data.csv', index=False)
